# %%
import pandas as pd
import numpy as np
#import * from config
# %matplotlib notebook
import matplotlib.pyplot as plt
from scipy import optimize

# %%
file_inven_SSA = "Data_Zillow/InventoryMeasure_SSA_Zip_Public.csv"
file_inven = "Data_Zillow/InventoryMeasure_Zip_Public.csv"
df_inven_SSA = pd.read_csv(file_inven_SSA)
df_inven = pd.read_csv(file_inven)
df_inven.head()
# Out:
#    RegionName RegionType      City CountyName              Metro  \
# 0       10025        Zip  New York   New York           New York
# 1       60657        Zip   Chicago       Cook            Chicago
# 2       10023        Zip  New York   New York           New York
# 3       75070        Zip  McKinney     Collin  Dallas-Fort Worth
# 4       77494        Zip      Katy     Harris            Houston
#
#   StateFullName DataTypeDescription  2010-01  2010-02  2010-03   ...     \
# 0      New York           All Homes      204      206      242   ...
# 1      Illinois           All Homes      670      730      827   ...
# 2      New York           All Homes      263      276      308   ...
# 3         Texas           All Homes      902      935     1056   ...
# 4         Texas           All Homes      807      828      925   ...
#
#    2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  \
# 0      142      189      177      139      133      159      166      194
# ...

# %%
zip_test = input("Please input the test zip code: ")
# Out:
# Please input the test zip code: 92037

# %%
df_test = df_inven[df_inven["RegionName"] == int(zip_test)]
df_test = df_test.reset_index()

# %%
num = len(df_test.columns)
columns_info = df_test.columns

inven = []
dict_test = df_test.to_dict()
dict_test
for i in range(8,num):
    inven.append(dict_test[columns_info[i]][0])

# %%
inven_num = len(inven)

# %%
mon_1 = [] 
mon_2 = []
mon_3 = [] 
mon_4 = [] 
mon_5 = [] 
mon_6 = [] 
mon_7 = [] 
mon_8 = [] 
mon_9 = [] 
mon_10 = [] 
mon_11 = [] 
mon_12 = []
for j in range(0,12*int(inven_num/12),12):
    mon_1.append(inven[j])
    mon_2.append(inven[j+1])
    mon_3.append(inven[j+2])
    mon_4.append(inven[j+3])
    mon_5.append(inven[j+4])
    mon_6.append(inven[j+5])
    mon_7.append(inven[j+6])
    mon_8.append(inven[j+7])
    mon_9.append(inven[j+8])
    mon_10.append(inven[j+9])
    mon_11.append(inven[j+10])
    mon_12.append(inven[j+11])

# %%
x = range(2010,2010+len(mon_1))
plt.plot(x,mon_1)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
plt.figure()
df_inven_SSA.head()
df_test = df_inven_SSA[df_inven_SSA["RegionName"] == int(zip_test)]
df_test = df_test.reset_index()
num = len(df_test.columns)
columns_info = df_test.columns
inven = []
dict_test = df_test.to_dict()
for i in range(8,num):
    inven.append(dict_test[columns_info[i]][0])

inven_num = len(inven)
mon_1 = [] 
mon_2 = []
mon_3 = [] 
mon_4 = [] 
mon_5 = [] 
mon_6 = [] 
mon_7 = [] 
mon_8 = [] 
mon_9 = [] 
mon_10 = [] 
mon_11 = [] 
mon_12 = []
print(inven_num)
sum = []
for j in range(0,12*int(inven_num/12),12):
    mon_1.append(inven[j])
    mon_2.append(inven[j+1])
    mon_3.append(inven[j+2])
    mon_4.append(inven[j+3])
    mon_5.append(inven[j+4])
    mon_6.append(inven[j+5])
    mon_7.append(inven[j+6])
    mon_8.append(inven[j+7])
    mon_9.append(inven[j+8])
    mon_10.append(inven[j+9])
    mon_11.append(inven[j+10])
    mon_12.append(inven[j+11])
    this_year = 0
    for k in range(12):
        this_year += inven[j+k]
    sum.append(this_year)

plt.plot(x,mon_1,x,mon_2,x,mon_3,x,mon_4,x,mon_5,x,mon_6)
plt.plot(x,mon_7,x,mon_8,x,mon_9,x,mon_10,x,mon_11,x,mon_12)

plt.grid()
plt.title(f"Inventory of Each Month in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Year")
plt.ylabel("Inventory")
plt.legend(["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"],loc="upper right")
plt.show()
plt.savefig("figures/Inventory_over_year_month.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# 102

# %%
plt.figure()
plt.plot(x,sum)
plt.grid()
plt.title(f"Inventory of Each Year in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Year")
plt.ylabel("Inventory")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0,0.5,'Inventory')

# %%
def f_1(x, A, B):
    return A*x + B

x1 = np.arange(2010, 2017, 0.1)
A1, B1 = optimize.curve_fit(f_1, x, sum)[0]
y1 = A1*x1 + B1
plt.plot(x1,y1,"k.")
plt.legend(["Invertory","Linear model"],loc="upper right")
plt.show()
plt.savefig("figures/Inventory_over_year.png")

# %%
inven_2018 = A1 * 2018 + B1
inven_2019 = A1 * 2019 + B1

# %%
popu_file = ["Data_Zillow/estimate_2010.csv", 
             "Data_Zillow/estimate_2011.csv",
             "Data_Zillow/estimate_2012.csv",
             "Data_Zillow/estimate_2013.csv",
             "Data_Zillow/estimate_2014.csv",
             "Data_Zillow/estimate_2015.csv",
             "Data_Zillow/estimate_2016.csv",
             ]
population = []
for csv_path in popu_file:
    df_popu_0 = pd.read_csv(csv_path)
    df_new = df_popu_0.loc[df_popu_0["ZIP"] == int(zip_test)]
    population.append(df_new["POPULATION"].sum())

plt.figure()
x2 = range(2010,2010+len(population))
plt.plot(x2,population)

plt.grid()
plt.title(f"Population in Zip Code {zip_test} Region from 2010 to 2016")
plt.xlabel("Year")
plt.ylabel("Population")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0,0.5,'Population')

# %%
x2_test = np.arange(2010, 2016, 0.1)
A2, B2 = optimize.curve_fit(f_1, x2, population)[0]
y2 = A2*x2_test + B2
plt.plot(x2_test,y2,"k.")
plt.legend(["Population","Linear Model"],loc="best")
plt.savefig("figures/Population_over_year.png")

# %%
popu_2018 = A2 * 2018 + B2
popu_2019 = A2 * 2019 + B2

# %%
#### Mortgage Rate Calculation ####
df_mort = pd.read_excel("Data_Zillow/MortgageRate.xlsx")
#print(df_mort["Week"].dtypes)
mort_num = len(df_mort["Week"])

for i in range(mort_num):
    df_mort.loc[i,"Year"] = df_mort.loc[i,"Week"].strftime("%Y")
    df_mort.loc[i,"Month"] = df_mort.loc[i,"Week"].strftime("%Y%m")

# %%
df_mort["Year"] = df_mort["Year"].astype("int")
df_mort["Month"] = df_mort["Month"].astype("int")
df_mort_group = df_mort.groupby(["Year"])
df_mort_year = df_mort_group["30 years"].mean()
df_mort_group_month = df_mort.groupby(["Month"])
df_mort_month = df_mort_group_month["30 years"].mean()

# %%
mort_year = []
mort_month = []
for year in range(1990,2018):
    mort_year.append(df_mort_year[year])

## No need to do linear regression for each month
    
x3 = range(1990,2018)
plt.figure()
plt.plot(x3,mort_year)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
x3_test = np.arange(1990, 2017, 0.5)
A3, B3 = optimize.curve_fit(f_1, x3, mort_year)[0]
y3 = A3*x3_test + B3
plt.plot(x3_test,y3,"k.")
plt.grid()
plt.title(f"Mortgage in Zip Code {zip_test} Region from 1990 to 2017")
plt.xlabel("Year")
plt.ylabel("Mortgage")
plt.legend(["Mortgage","Linear Model"],loc="upper right")
plt.show()
plt.savefig("figures/Mortgage_over_year.png")

# %%
mort_2018 = A3 * 2018 + B3
mort_2018 = A3 * 2018 + B3

# %%
df_price = pd.read_csv("Data_Zillow/MedianHomeValuePerSqf_samples.csv")
df_price_region = df_price.loc[df_price["regionname"] == int(zip_test)]
df_price_region = df_price_region.reset_index()
price_dict = df_price_region.to_dict()
#print(price_dict)
time_line = ["2010-01","2010-02","2010-03","2010-04","2010-05","2010-06",
             "2010-07","2010-08","2010-09","2010-10","2010-11","2010-12",
             "2011-01","2011-02","2011-03","2011-04","2011-05","2011-06",
             "2011-07","2011-08","2011-09","2011-10","2011-11","2011-12",
             "2012-01","2012-02","2012-03","2012-04","2012-05","2012-06",
             "2012-07","2012-08","2012-09","2012-10","2012-11","2012-12",
             "2013-01","2013-02","2013-03","2013-04","2013-05","2013-06",
             "2013-07","2013-08","2013-09","2013-10","2013-11","2013-12",
             "2014-01","2014-02","2014-03","2014-04","2014-05","2014-06",
             "2014-07","2014-08","2014-09","2014-10","2014-11","2014-12",
             "2015-01","2015-02","2015-03","2015-04","2015-05","2015-06",
             "2015-07","2015-08","2015-09","2015-10","2015-11","2015-12",
             "2016-01","2016-02","2016-03","2016-04","2016-05","2016-06",
             "2016-07","2016-08","2016-09","2016-10","2016-11","2016-12",
             "2017-01","2017-02","2017-03","2017-04","2017-05","2017-06",
             "2017-07","2017-08","2017-09","2017-10","2017-11","2017-12"
            ]
price_month = []
price_year = []
count = 0
temp = 0
for i in time_line:
    price_month.append(price_dict[i][0])
    temp += price_dict[i][0]
    count += 1
    if count == 12:
        count = 0
        price_year.append(temp/12)
        temp = 0
x4 = range(2010,2018)
x4_month_count = range(len(price_month))

# %%
plt.figure()
plt.plot(x4,price_year)
plt.grid()
plt.title(f"House Price per Square meters in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Year")
plt.ylabel("House Price per Square meters")
plt.legend(["House Price per Square meters"],loc="best")
plt.show()
plt.savefig("figures/House_Price_over_year.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
plt.figure()
plt.plot(x4_month_count,price_month)
plt.grid()
plt.title(f"House Price in Each Month per Square meters in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Month Number Counts from 2010 to 2017")
plt.ylabel("House Price per Square meters")
plt.legend(["House Price per Square meters"],loc="best")
plt.show()
plt.savefig("figures/House_Price_over_year_each_month.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
# choose from 2013 to 2017 to set up linear model

# %%
price_year2 = price_year[3:8]
x4 = range(2013,2018)
plt.figure()
plt.plot(x4,price_year2)
x4_test = np.arange(2013,2017,0.1)
A4, B4 = optimize.curve_fit(f_1, x4, price_year2)[0]
y4 = A4*x4_test + B4
plt.plot(x4_test,y4,'k.')
plt.grid()
plt.title(f"House Price in Each Month per Square meters in Zip Code {zip_test} Region from 2013 to 2017")
plt.xlabel("Year")
plt.ylabel("House Price per Square meters")
plt.legend(["House Price per Square meters","Linear Model"],loc="best")
plt.show()
plt.savefig("figures/House_Price_over_year_w_model.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
# This is used for verification of linear design model
price_2018 = A4 * 2018 + B4 
price_2019 = A4 * 2019 + B4

# %%
## linear model relation between price and mortgage/inventory/population 
## from 2010 to 2016

# %%
population_t = population
mort_year_t = mort_year[-8:-1]
inven_year_t = sum[0:7]
price_year_t = price_year[0:7] 
x0 = range(2010,2017)

# %%
def f_0(x, y, z, A, B, C, D):
    return A*x + B*y + C*z + D

# %%
plt.figure()
plt.plot(population_t,price_year_t,"o")


A5, B5 = optimize.curve_fit(f_1, population_t, price_year_t)[0]
y5 = A5*np.array(population_t) + B5
plt.plot(population_t,y5,'k.-')
plt.grid()
plt.title(f"Relationship between Population & House Price in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Population from 2010 to 2017")
plt.ylabel("House Price per Square meters")
plt.legend(["Relationship","Linear Model"],loc="best")
plt.show()
plt.savefig("figures/House_Price_Population.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
month_list = [201001,201002,201003,201004,201005,201006,201007,201008,201009,201010,201011,201012,
              201101,201102,201103,201104,201105,201106,201107,201108,201109,201110,201111,201112,
              201201,201202,201203,201204,201205,201206,201207,201208,201209,201210,201211,201212,
              201301,201302,201303,201304,201305,201306,201307,201308,201309,201310,201311,201312,
              201401,201402,201403,201404,201405,201406,201407,201408,201409,201410,201411,201412,
              201501,201502,201503,201504,201505,201506,201507,201508,201509,201510,201511,201512,
              201601,201602,201603,201604,201605,201606,201607,201608,201609,201610,201611,201612,
              201701,201702,201703,201704,201705,201706,201707,201708,201709,201710,201711,201712
             ]
mort_month = []
for i in month_list:
    mort_month.append(df_mort_month[i])
    
plt.figure()
plt.scatter(mort_month,price_month)

plt.grid()
plt.title(f"Relationship between Mortgage & House Price in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Mortgage from 2010 to 2017")
plt.ylabel("House Price per Square meters")
plt.legend(["No Obvious Relationship"],loc="best")
plt.show()
plt.savefig("figures/Mortgage_Population.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
####  Conclusion  No Relationship between mortgage and house price

# %%
### price v.s. inventory
inventory = sum
plt.figure()
plt.scatter(inventory,price_year)
plt.grid()
plt.title(f"Relationship between Inventory & House Price in Zip Code {zip_test} Region from 2010 to 2017")
plt.xlabel("Inventory from 2010 to 2017")
plt.ylabel("House Price per Square meters")
plt.legend(["No Obvious Relationship"],loc="best")
plt.show()
plt.savefig("figures/House_Price_Inventory.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
inventory_month = inven[0:96]
plt.figure()
plt.scatter(inventory_month,price_month)
#plt.xscale('log')
plt.grid()
plt.title(f"Relationship between Inventory & House Price in Zip Code {zip_test} Region from 2010 to 2017\n in Each month")
plt.xlabel("Inventory from 2010 to 2017")
plt.ylabel("House Price per Square meters")
plt.legend(["No Obvious Relationship"],loc="best")
plt.show()
plt.savefig("figures/House_Price_Inventory_Month.png")
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
### We can use each month to predict the whole year, but no relationship between inventory and house price per suqare

# %%
#A0, B0, C0, D0 = optimize.curve_fit(f_0, population_t, inven_year_t, mort_year_t, price_year_t)[0]
#x0_test = np.arange(2010, 2016, 0.1)
#y0_test = A0*x0_test + B0*x0_test + C0*x0_test + D0
#plt.figure()
#plt.plot(x0,price_year_t)
#plt.plot(x0_test, y0_test, "k.")

# %%
df_zvalue = pd.read_csv("Data_Zillow/SD_Zillow.csv")
df_zvalue
# Out:
#     Unnamed: 0      id   latitude   longitude                     name  \
# 0            0  116625  32.919433 -117.141434                Mira Mesa
# 1            1  118673  32.870593 -117.207369          University City
# 2            2  117557  32.970952 -117.126621       Rancho Penasquitos
# 3            3  273140  32.937439 -117.208103            Carmel Valley
# 4            4  275127  33.033704 -117.078306          Rancho Bernardo
# 5            5  274717  32.746122 -117.129668               North Park
# 6            6   46087  32.847885 -117.254800                 La Jolla
# 7            7  403253  32.578416 -117.059537           Otay Mesa West
# 8            8  272875  32.687068 -117.043595             Bay Terraces
# 9            9  117156  32.804830 -117.237967            Pacific Beach
# 10          10  118541  32.834895 -117.062776              Tierrasanta
# 11          11  268076  32.816830 -117.174289     Clairemont Mesa East
# ...
